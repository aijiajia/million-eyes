# %%
import numpy as np
import matplotlib.pyplot as plt
rng = np.random.RandomState(1)
# 指定形状的矩阵
# rng.rand(2, 2)
# 2行2列乘2行200列的矩阵
X = np.dot(rng.rand(2, 2), rng.randn(2, 200)).T
# print(X.shape)
# print(X)
# print(X[:3, :].shape)
plt.scatter(X[:, 0], X[:, 1])
plt.axis('equal');
plt.show()
